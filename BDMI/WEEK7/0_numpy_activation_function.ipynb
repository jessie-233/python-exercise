# %%
# %matplotlib inline  
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# 生成x轴上的数据:从-3到3，总共有50个点
x = np.linspace(-1, 1, 50)
# 定义一个线性方程
y1 = 2 * x + 1
# 定义一个二次方程
y2 = x ** 2
# 设置x轴的取值范围为：-1到2
plt.xlim(-1, 2)
# 设置y轴的取值范围为：-1到3
plt.ylim(-1, 3)
# 设置x轴的文本，用于描述x轴代表的是什么
plt.xlabel("I am x")
# 设置y轴的文本，用于描述y轴代表的是什么
plt.ylabel("I am y")
plt.plot(x, y2)
# 绘制红色的线宽为1虚线的线条
plt.plot(x, y1, color='red', linewidth=1.0, linestyle='--')
# 显示图表
plt.show()

# %% [markdown]
# # 激活函数

# %% [markdown]
# ### ReLU函数

# %% [markdown]
# ReLU函数是Softplus函数的钝化版本。ReLU函数有几种推广版本：
#
# 绝对值整流（absolute value rectification）。
#
# 渗漏整流线性单元（Leaky ReLU）。

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(-5,5,100)

# %%
relu = lambda x: np.maximum(x, 0)

# %%
plt.plot(x, relu(x), color='blue', lw=2)

# %% [markdown]
# ### PReLU

# %% [markdown]
# $ReLU(x) = max(0,x)$
#
# 参数化整流线性单元（parametric ReLU）或者PReLU。

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-5,5,100)
pr = lambda array: [i*0.1 if i <0 else i for i in array] 
plt.plot(x, pr(x), color='blue', lw=2)

# %% [markdown]
# ### Softplus函数

# %% [markdown]
# Softplus函数是ReLu函数的软化版本。$ \log_2(1+e^x) $

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(-5,5,100)
softplus = lambda x: np.log(1.0 + np.exp(x))
plt.plot(x, softplus(x), color='blue', lw=2)

# %% [markdown]
# ### sigmoid函数
#
# $sigmoid(x)=\frac{1}{1+e^{-x}}$

# %%
x = np.linspace(-5,5,100)
sigmoid = lambda x: 1 / (1 + np.exp(-x))
plt.plot(x,sigmoid(x), color='red', lw=2)

# %% [markdown]
# ### 饱和型S函数

# %%
x = np.linspace(-5,5,100)
pr = lambda array: [0 if i <0 else 1 for i in array] 
plt.plot(x, pr(x), color='blue', lw=2)

# %% [markdown]
# ### logit函数
# $log_2\frac{x}{1-x}$

# %%
x = np.linspace(0.00000000001,0.9999999,100)
logit = lambda x: np.log(x / (1 - x))
plt.plot(x,logit(x), color='blue', lw=2)

# %% [markdown]
# ### SoftSign函数

# %%
x = np.linspace(-5,5,100)
softsign = lambda x: x / (1 + np.absolute(x))
plt.plot(x,softsign(x), color='blue', lw=2)

# %% [markdown]
# ### tanh函数
#
# $tanh(x)=\frac{e^x-e^{-x}}{e^x+e^{-x}}$

# %%
x = np.linspace(-5,5,100)
th = lambda x: np.tanh(x)
plt.plot(x,th(x), color='blue', lw=2)

# %% [markdown]
# ### hard tanh函数

# %%
def hard_tanh(x):
    if abs(x)<1:
        return x
    else:
        if x>1: 
            return 1
        else:
            return -1
x = np.linspace(-5,5,100)
htan = lambda xs: [hard_tanh(x) for x in xs] 
plt.plot(x,htan(x), color='blue', lw=2)

# %% [markdown]
# ### softmax函数
# $g(z_m)=\frac{e^{z_m}}{\sum_k {e^{z_k}}}$

# %%
import math
w=[1,2,3,4,5,6,7,8,9]
w_exp=[math.exp(i) for i in w]
print(w_exp)
# Out:
# [2.718281828459045, 7.38905609893065, 20.085536923187668, 54.598150033144236, 148.4131591025766, 403.4287934927351, 1096.6331584284585, 2980.9579870417283, 8103.083927575384]

# %%
sum_w_exp = sum(w_exp)

# %%
softmax = [round(i / sum_w_exp, 3) for i in w_exp]

# %%
print(softmax)
# Out:
# [0.0, 0.001, 0.002, 0.004, 0.012, 0.031, 0.086, 0.233, 0.632]

# %%
print(sum(softmax))
# Out:
# 1.001

# %%
plt.plot(softmax)
